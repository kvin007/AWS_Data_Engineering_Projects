# %% [markdown]
# <h1> Assesing the data quality </h1>

# %% [markdown]
# <h3> Reviews data from Glassdoor </h3>

# %%
import pandas as pd

# %%
df_reviews = pd.read_csv('glassdoor_reviews.csv')

# %%
df_reviews.head()
# Out:
#    Unnamed: 0  column_label       firm date_review  \
# 0           1             1  Sotheby-s  2021-05-25
# 1           2             1  Sotheby-s  2021-05-25
# 2           3             1  Sotheby-s  2021-05-24
# 3           4             1  Sotheby-s  2021-05-22
# 4           5             1  Sotheby-s  2021-05-15
#
#                          job_title                             current  \
# 0                Financial Analyst   Former Employee, more than 1 year
# 1                    Administrator                     Former Employee
# 2   Client Services Representative   Former Employee, more than 1 year
# 3               Anonymous Employee                    Current Employee
# 4                    Administrator  Current Employee, less than 1 year
#
#                    location  overall_rating  work_life_balance  \
# 0              New York, NY               1                1.0
# 1                 Hong Kong               4                4.0
# ...

# %%
# Checking if any column has missing values
df_reviews.columns[df_reviews.isna().any()].tolist()
# Out:
# ['location',
#  'work_life_balance',
#  'culture_values',
#  'diversity_inclusion',
#  'career_opp',
#  'comp_benefits',
#  'senior_mgmt',
#  'headline',
#  'cons',
#  'use']

# %% [markdown]
# Since we won't consider those columns into our analysis, no treatment is made. We could remove then or replace them with certain values

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838566 entries, 0 to 838565
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           838566 non-null  int64
#  1   column_label         838566 non-null  int64
#  2   firm                 838566 non-null  object
#  3   date_review          838566 non-null  object
#  4   job_title            838566 non-null  object
#  5   current              838566 non-null  object
#  6   location             541228 non-null  object
#  7   overall_rating       838566 non-null  int64
#  8   work_life_balance    688672 non-null  float64
#  9   culture_values       647193 non-null  float64
#  10  diversity_inclusion  136066 non-null  float64
#  11  career_opp           691065 non-null  float64
#  12  comp_benefits        688484 non-null  float64
#  13  senior_mgmt          682690 non-null  float64
# ...

# %%
df_reviews.columns
# Out:
# Index(['Unnamed: 0', 'column_label', 'firm', 'date_review', 'job_title',
#        'current', 'location', 'overall_rating', 'work_life_balance',
#        'culture_values', 'diversity_inclusion', 'career_opp', 'comp_benefits',
#        'senior_mgmt', 'recommend', 'ceo_approv', 'outlook', 'headline', 'pros',
#        'cons', 'use'],
#       dtype='object')

# %%
list(df_reviews['job_title'].unique())[:20]
# Out:
# [' Financial Analyst',
#  ' Administrator',
#  ' Client Services Representative',
#  ' Anonymous Employee',
#  ' Administration',
#  ' Summer Intern',
#  ' Staff',
#  ' Exhibition Assistant',
#  ' Business Analyst',
#  ' Floater',
#  ' Graphic Designer',
#  ' In House Picture Framer',
#  ' Researcher',
#  ' Fine Art Specialist',
#  ' Special Events Manager',
#  ' Department Assistant',
#  ' Data Analyst',
#  ' Project Administrator',
#  ' Specialist',
#  ' Teacher']

# %% [markdown]
# From the previous cell, we can see that there are multiple categories for jobs, and that the titles need trimming to have consistent names.
# Also that there is no consistency between names which is an indicator that we may need to capitalize each word for the names

# %%
sorted(df_reviews['firm'].unique())
# Out:
# ['AFH-Wealth-Management',
#  'AJ-Bell',
#  'ALDI',
#  'AQA',
#  'ASDA',
#  'ASOS',
#  'AXA-UK',
#  'Abcam',
#  'Abertawe-Bro-Morgannwg-University-Health-Board',
#  'Accenture',
#  'Accor',
#  'Achieving-for-Children',
#  'ActionCOACH',
#  'Active-Care-Group',
#  'Adecco',
#  'Age-UK-The-National-Charity',
#  'AlixPartners',
#  'American-Express',
#  'Amey',
#  'Angard-Staffing',
#  'Anglian-Water',
#  'Anglo-American',
#  'Animal-and-Plant-Health-Agency',
#  'Aon',
#  'Apple',
#  'Arcadia',
#  'Arnold-Clark',
#  'AstraZeneca',
#  'Aviva',
#  'B-and-M-Retail',
#  'B-and-Q',
#  'BAT',
#  'BBC',
#  'BDO',
#  'BHS',
#  'BIS',
#  'BNP-Paribas',
#  'BNY-Mellon',
#  'BP',
#  'BPP-Holdings',
#  'BT',
#  'Babcock-International-Group',
#  'Babylon-Health',
#  'Bain-and-Company',
#  'Balfour-Beatty',
#  'Bannatyne-Group',
#  'Barchester-Healthcare',
#  'Barclays',
#  'Barnardo-s',
#  'Barnet-and-Chase-Farm-Hospitals-NHS-Trust',
#  'Barnett-Waddingham',
#  'Barratt-Developments',
# ...

# %% [markdown]
# We can see that the company names have a hyphen character instead a space character. Some companies such as "McDonald's" are written as "McDonald-s", meaning we have a special case when the company ends with "-s"

# %%
df_companies = pd.read_csv('Forbes Top2000 2017.csv')

# %%
df_companies.head()
# Out:
#    Unnamed: 0   Rank                  Company        Country  Sales  Profits  \
# 0         NaN      1                     ICBC          China  151.4     42.0
# 1         NaN      2  China Construction Bank          China  134.2     35.0
# 2         NaN      3       Berkshire Hathaway  United States  222.9     24.1
# 3         NaN      4           JPMorgan Chase  United States  102.5     24.2
# 4         NaN      5              Wells Fargo  United States   97.6     21.9
#
#    Assets  Market Value      Sector             Industry
# 0  3473.2         229.8  Financials          Major Banks
# 1  3016.6         200.5  Financials       Regional Banks
# 2   620.9         409.9  Financials  Investment Services
# 3  2513.0         306.6  Financials          Major Banks
# 4  1943.4         274.4  Financials          Major Banks

# %%
df_companies.columns[df_companies.isna().any()].tolist()
# Out:
# ['Unnamed: 0', 'Sector', 'Industry']

# %%
df_companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    0 non-null      float64
#  1    Rank         2000 non-null   int64
#  2   Company       2000 non-null   object
#  3   Country       2000 non-null   object
#  4   Sales         2000 non-null   float64
#  5   Profits       2000 non-null   float64
#  6   Assets        2000 non-null   float64
#  7   Market Value  2000 non-null   float64
#  8   Sector        1803 non-null   object
#  9   Industry      1509 non-null   object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 156.4+ KB
